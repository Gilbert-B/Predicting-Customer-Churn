# %% [markdown]
# <a href="https://colab.research.google.com/github/eaedk/Machine-Learning-Tutorials/blob/main/ML_Step_By_Step_Guide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro
# ## General
# Machine learning allows the user to feed a computer algorithm an immense amount of data and have the computer analyze and make data-driven recommendations and decisions based on only the input data.
# In most of the situations we want to have a machine learning system to make **predictions**, so we have several categories of machine learning tasks depending on the type of prediction needed: **Classification, Regression, Clustering, Generation**, etc.
#
# **Classification** is the task whose goal is the prediction of the label of the class to which the input belongs (e.g., Classification of images in two classes: cats and dogs).
# **Regression** is the task whose goal is the prediction of numerical value(s) related to the input (e.g., House rent prediction, Estimated time of arrival ).
# **Generation** is the task whose goal is the creation of something new related to the input (e.g., Text translation, Audio beat generation, Image denoising ). **Clustering** is the task of grouping a set of objects in such a way that objects in the same group (called a **cluster**) are more similar (in some sense) to each other than to those in other **clusters** (e.g., Clients clutering).
#
# In machine learning, there are learning paradigms that relate to one aspect of the dataset: **the presence of the label to be predicted**. **Supervised Learning** is the paradigm of learning that is applied when the dataset has the label variables to be predicted, known as ` y variables`. **Unsupervised Learning** is the paradigm of learning that is applied when the dataset has not the label variables to be predicted. **Self-supervised Learning** is the paradigm of learning that is applied when part of the X dataset is considere as the label to be predicted (e.g., the Dataset is made of texts and the model try to predict the next word of each sentence).
#
# ## Notebook overview
#
# This notebook is documents a project that is aimed at finding the likelihood of a customer leaving our target organization, the key indicators of the churn as well as the retention strategies that can be implemented to avert this problem.

# %% [markdown]
# # Setup

# %% [markdown]
# ## Installation
# Here is the section to install all the packages/libraries that will be needed to tackle the challlenge.

# %%
#%pip install pandas-profiling
#%pip install pivottablejs
#%pip install pyqt5
#%pip install python-tk 
#%pip install statsmodels

# %% [markdown]
# ## Importation
# Here is the section to import all the packages/libraries that will be used through this notebook.

# %%
# Data handling
import pandas as pd
import numpy as np
from statistics import mean
from forex_python.converter import CurrencyRates
from babel.numbers import format_currency
import datetime as dt
import pandas_profiling as pp

# Vizualisation (Matplotlib, Plotly, Seaborn, etc. )
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sn

# %% [markdown]
# # Data Loading
# Here is the section to load the datasets (train, eval, test) and the additional files

# %%
data = pd.read_csv('Telco_Customer_churn.csv')

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# # Exploratory Data Analysis: EDA
# Here is the section to **inspect** the datasets in depth, **present** it, make **hypotheses** and **think** the *cleaning, processing and features creation*.

# %% [markdown]
# ### Dataset overview
#
# Have a look at the loaded datsets using the following methods: `.head(), .info()`

# %%
#Taking a look at the shape of our data
data.shape
# Out:
# (7043, 21)

# %%
# A quick look at the head of our dataset
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# A look at the last 5 rows in our data set 
data.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
#Look at the columns in the dataset and their data types
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
# runing a pandas profiling on the data to get a wholistic view of the data 
pp.ProfileReport(data)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv3.6.2&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-02-24 17:20:11.764715&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# ## Issues with the data

# %% [markdown]
# 1. more than 600 cutomers have 0 months tenure.

# %% [markdown]
# ## How to deal with the Issues

# %% [markdown]
# 1. Investigate and see if the tenure of these customers are actually 0

# %% [markdown]
# ## Questions

# %% [markdown]
# 1. What is our churning rate?
# 2. What type of contract churns more customers?
# 3. What type of internet service churns more customers?
# 4. What is the longest period of time we have had a customer?
# 5. What is the shortest period of time we have had a customer ?
# 6. Which gender churns more ?
# 7. How many senior citizens are in the data set and what is their proportion?
# 8. How does the proportion of churned customers differ between senior citizens and non-senior citizens?
# 9. What is the relationship between tenure and churn ?
# 10. What is the Relationship between paperlessbilling and Churn?
# 11. hat is the Relationship between payment method and churn?

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# Null Hypothesis : The longer a customer's tenure , the lesser the likelihood that the customer will churn
#
# Alternate Hypothesis: A customers tenure does not determine the likelihood of a churn

# %% [markdown]
# ## Answering the Questions

# %% [markdown]
# ##### 1. What is our churn rate?

# %%
data1= data.groupby(['Churn'])['customerID'].count().reset_index()
data1.sort_values(['customerID'], ascending = True, inplace=True)
data1
# Out:
#   Churn  customerID
# 1   Yes        1869
# 0    No        5174

# %%
mydata = data1['customerID']
mycolors = ['maroon', 'teal']
myexplode = (0, 0.1)
plt.pie(mydata, labels=data1['Churn'],autopct='%1.1f%%', startangle=-20, shadow=True, colors=mycolors, explode=myexplode)
plt.title('Customer Churn Rate')
plt.axis('equal')
plt.show()

# %% [markdown]
# From the figure above, our churn rate is 26.5%

# %% [markdown]
# ##### 2. What type of contract churns  more customers?

# %%
Contractdf = data[['Contract','Churn']].copy()
Contractdf
# Out:
#             Contract Churn
# 0     Month-to-month    No
# 1           One year    No
# 2     Month-to-month   Yes
# 3           One year    No
# 4     Month-to-month   Yes
# ...              ...   ...
# 7038        One year    No
# 7039        One year    No
# 7040  Month-to-month    No
# 7041  Month-to-month   Yes
# 7042        Two year    No
#
# [7043 rows x 2 columns]

# %%
count= Contractdf.groupby("Contract")["Churn"].value_counts().unstack()
count
# Out:
# Churn             No   Yes
# Contract
# Month-to-month  2220  1655
# One year        1307   166
# Two year        1647    48

# %%
sn.catplot(x="Contract", hue ="Churn",kind="count", color= "maroon", data=Contractdf)

# %% [markdown]
# We can deduce that month to month contracts have the highest customer churn with two-year contracts having the lowest

# %% [markdown]
# ##### 3. What type of internet service churns more customers?

# %%
counts= data.groupby(['InternetService','Churn']).size().unstack()
counts
# Out:
# Churn              No   Yes
# InternetService
# DSL              1962   459
# Fiber optic      1799  1297
# No               1413   113

# %%
# Normalize the data to show proportions
counts = counts.div(counts.sum(axis=1), axis=0)
counts
# Out:
# Churn                  No       Yes
# InternetService
# DSL              0.810409  0.189591
# Fiber optic      0.581072  0.418928
# No               0.925950  0.074050

# %%
counts.plot(kind='bar', stacked=True, color=['teal','maroon'],rot=15)
plt.xlabel('Internet Service')
plt.ylabel('Proportion of Customers')
plt.title('Churn by Internet Service')
plt.legend(['Did Not Churn', 'Churned'])

plt.show()

# %% [markdown]
# Customers using fibre optic internet service had a higher churn rate

# %% [markdown]
# ##### 4. What is the longest period of time we have had a customer?

# %%
max_tenure = data["tenure"].max()


f'The longest period we have retained a customer is {max_tenure} months'
# Out:
# 'The longest period we have retained a customer is 72 months'

# %% [markdown]
# ##### 5. What is the shortest period of time we have had a customer ?

# %%
min_tenure = data["tenure"].min()

f'The shortest period we have had a customer is {min_tenure} months'
# Out:
# 'The shortest period we have had a customer is 0 months'

# %% [markdown]
# ##### 6. Which gender churns more ?

# %%
#count the number of males
gender_counts = data['gender'].value_counts()
num_males=gender_counts['Male']
f'The total number of Males is {num_males}'
# Out:
# 'The total number of Males is 3555'

# %%
#count the number of females
num_females=gender_counts['Female']
f'The total number of Males is {num_females}'
# Out:
# 'The total number of Males is 3488'

# %%
# create a bar chart to visualize the results
labels = ['Female', 'Male']
values = [len(data) - num_females, num_males]
plt.bar(labels, values)
plt.title('Distribution of Gender')
plt.xlabel('Gender')
plt.ylabel('Number of Customers')
plt.show()

# %%
# finding the number of  customers who churn and those that did not by gender
gender= data.groupby("gender")["Churn"].value_counts().unstack()
gender
# Out:
# Churn     No  Yes
# gender
# Female  2549  939
# Male    2625  930

# %%
# calculating the ratio of yes to no by gender 
gender['ratio'] = gender['Yes'] / gender['No']
gender
# Out:
# Churn     No  Yes     ratio
# gender
# Female  2549  939  0.368380
# Male    2625  930  0.354286

# %%
mean_ratio_by_gender = gender.groupby('gender')['ratio'].mean()
mean_ratio_by_gender
# Out:
# gender
# Female    0.368380
# Male      0.354286
# Name: ratio, dtype: float64

# %%
f'The mean ratio of of men who Female who churned is slightly higher than that of males'
# Out:
# 'The mean ratio of of men who Female who churned is slightly higher than that of males'

# %% [markdown]
# ##### 7. How many senior citizens are in the data set and what is their proportion?

# %%
#count the number of senior citizens
num_senior = data['SeniorCitizen'].sum()
f'The number of senior citizens is {num_senior}'
# Out:
# 'The number of senior citizens is 1142'

# %%
# calculate the proportion of senior citizens
prop_senior = num_senior / len(data)
f'The proportion of senior citizens of the entire data set is {prop_senior:.2f}'
# Out:
# 'The proportion of senior citizens of the entire data set is 0.16'

# %%
# create a bar chart to visualize the results
labels = ['Non-senior', 'Senior']
values = [len(data) - num_senior, num_senior]
plt.bar(labels, values)
plt.title('Distribution of Senior Citizens')
plt.xlabel('Senior Citizen Status')
plt.ylabel('Number of Customers')
plt.show()

# %% [markdown]
# ##### 8.How does the proportion of churned customers differ between senior citizens and non-senior citizens?

# %%
# calculate the proportion of churned customers for each seniorcitizen group
proportions = data.groupby('SeniorCitizen')['Churn'].apply(lambda x: (x=='Yes').mean())
proportions
# Out:
# SeniorCitizen
# 0    0.236062
# 1    0.416813
# Name: Churn, dtype: float64

# %%
# create a bar chart to visualize the results
labels = ['Non-senior', 'Senior']
values = proportions.values
plt.bar(labels, values)
plt.title('Proportion of Churned Customers')
plt.xlabel('Senior Citizen Status')
plt.ylabel('Proportion of Churned Customers')
plt.show()

# %% [markdown]
# From the diagram we see that 41% of senior citizen churned and 23 % of non senior citizens churned

# %% [markdown]
# ##### 9. What is the relationship between tenure and Churn

# %%
# convert churn column to binary values
data['Churn'] = data['Churn'].map({'Yes': 1, 'No': 0})

# %%
# create a scatter plot
plt.scatter(data['tenure'], data['Churn'])
plt.title('Relationship Between Tenure and Churn')
plt.xlabel('Tenure (months)')
plt.ylabel('Churn')
plt.show()

# calculate the correlation coefficient
corr = data['tenure'].corr(data['Churn'])
print('Correlation coefficient:', corr)
# Out:
# Correlation coefficient: -0.3522286701130779

# %% [markdown]
#  Even though we have a correlation co effiecient of -0.3522 from our grapgh, we can deduce that there is  no clear relationship between the tenure and Churn. Tenure of a customer is not a good predictor of their likelihood to churn.

# %% [markdown]
# ##### 10. Relationship between paperlessbilling and Churn

# %%
# convert PaperlessBilling column to binary values
data['PaperlessBilling'] = data['PaperlessBilling'].map({'Yes': 1, 'No': 0})

# %%
# create a scatter plot
plt.scatter(data['PaperlessBilling'], data['Churn'])
plt.title('Relationship Between PaperlessBilling and Churn')
plt.xlabel('PaperlessBilling')
plt.ylabel('Churn')
plt.show()

# calculate the correlation coefficient
corr = data['PaperlessBilling'].corr(data['Churn'])
print('Correlation coefficient:', corr)
# Out:
# Correlation coefficient: 0.19182533166646806

# %% [markdown]
# There is no correlation between PaperlesBilling and Churn

# %% [markdown]
# ##### 11. Relationship between payment method and churning

# %%
grouped = data.groupby(['PaymentMethod', 'Churn']).size().unstack()
grouped
# Out:
# Churn                         0     1
# PaymentMethod
# Bank transfer (automatic)  1286   258
# Credit card (automatic)    1290   232
# Electronic check           1294  1071
# Mailed check               1304   308

# %%
# Normalize the data to show proportions
grouped = grouped.div(grouped.sum(axis=1), axis=0)
grouped
# Out:
# Churn                             0         1
# PaymentMethod
# Bank transfer (automatic)  0.832902  0.167098
# Credit card (automatic)    0.847569  0.152431
# Electronic check           0.547146  0.452854
# Mailed check               0.808933  0.191067

# %%
grouped.plot(kind='bar', stacked=True, color=['teal','maroon'],rot=15)
plt.xlabel('Payment Method')
plt.ylabel('Proportion of Customers')
plt.title('Churn by Payment Method')
plt.legend(['Did Not Churn', 'Churned'])

plt.show()

# %% [markdown]
# Electronic Check issuers were more likely to churn than any other payment method

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# From our analysis, we fail to accept the Null Hypothesis; The longer a customer's tenure , the lesser the likelihood that the customer will churn.

# %% [markdown]
# # Feature Processing & Engineering
# Here is the section to **clean**, **process** the dataset and **create new features**.

# %% [markdown]
# ## Drop Duplicates

# %%
duplicates = data.duplicated()
print(data[duplicates])
# Out:
# Empty DataFrame
# Columns: [customerID, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# There are no Duplicate rows

# %% [markdown]
# ## Impute Missing Values

# %% [markdown]
# From our Data summary made with our pandas profiling, there are no missing values in our data

# %% [markdown]
# ## New Features Creation

# %%
data.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
# 5  9305-CDSKC  Female              0      No         No       8          Yes
# 6  1452-KIOVK    Male              0      No        Yes      22          Yes
# 7  6713-OKOMC  Female              0      No         No      10           No
# 8  7892-POOKP  Female              0     Yes         No      28          Yes
# 9  6388-TABGU    Male              0      No        Yes      62          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# ...

# %% [markdown]
# ## Features Encoding

# %%
# for columns with yes or no values, we map them to 1 or 0
data['Partner'] = data['Partner'].map({'Yes': 1, 'No': 0})
data['PhoneService'] = data['PhoneService'].map({'Yes': 1, 'No': 0})
data['Dependents'] = data['Dependents'].map({'Yes': 1, 'No': 0})

# %%
data.head(5)
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG  Female              0        1           0       1
# 1  5575-GNVDE    Male              0        0           0      34
# 2  3668-QPYBK    Male              0        0           0       2
# 3  7795-CFOCW    Male              0        0           0      45
# 4  9237-HQITU  Female              0        0           0       2
#
#    PhoneService     MultipleLines InternetService  OnlineSecurity  ...  \
# 0             0  No phone service             DSL             0.0  ...
# 1             1                No             DSL             1.0  ...
# 2             1                No             DSL             1.0  ...
# 3             0  No phone service             DSL             1.0  ...
# 4             1                No     Fiber optic             0.0  ...
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
# Create an instance of the OneHotEncoder class
encoder = OneHotEncoder()

# Fit the encoder to the "color" and "size" columns
encoder.fit(data[['MultipleLines', 'InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport'
                  ,'StreamingTV','StreamingMovies','Contract','PaymentMethod']])

# Transform the "color" and "size" columns using the encoder
encoded_array = encoder.transform(data[['MultipleLines', 'InternetService','OnlineSecurity','OnlineBackup','DeviceProtection','TechSupport'
                  ,'StreamingTV','StreamingMovies','Contract','PaymentMethod']]).toarray()

# Create a new DataFrame with the encoded values
encoded_df = pd.DataFrame(encoded_array, columns=encoder.get_feature_names(['color', 'size']))

# Concatenate the original DataFrame with the encoded DataFrame
df = pd.concat([df, encoded_df], axis=1)

# Display the final DataFrame
print(df)

# %% [markdown]
# ## Dataset Splitting

# %%
# Use train_test_split with a random_state, and add stratify for Classification

# %% [markdown]
# ## Features Scaling

# %%
# From sklearn.preprocessing use StandardScaler, MinMaxScaler, etc.

# %% [markdown]
# ## Optional: Train Dataset Balancing

# %%
# Use Over-sampling/Under-sampling methods, more details here: https://imbalanced-learn.org/stable/install.html

# %% [markdown]
# # Machine Learning Modeling
# Here is the section to **build**, **train**, **evaluate** and **compare** the models to each others.

# %% [markdown]
# ## Simple Model #001
#
# Please, keep the following structure to try all the model you want.

# %% [markdown]
# ### Create the Model

# %%
# Code here

# %% [markdown]
# ### Train the Model

# %%
# Use the .fit method

# %% [markdown]
# ### Evaluate the Model on the Evaluation dataset (Evalset)

# %%
# Compute the valid metrics for the use case # Optional: show the classification report

# %% [markdown]
# ### Predict on a unknown dataset (Testset)

# %%
# Use .predict method # .predict_proba is available just for classification

# %% [markdown]
# ## Simple Model #002

# %% [markdown]
# ### Create the Model

# %%
# Code here

# %% [markdown]
# ### Train the Model

# %%
# Use the .fit method

# %% [markdown]
# ### Evaluate the Model on the Evaluation dataset (Evalset)

# %%
# Compute the valid metrics for the use case # Optional: show the classification report

# %% [markdown]
# ### Predict on a unknown dataset (Testset)

# %%
# Use .predict method # .predict_proba is available just for classification

# %% [markdown]
# ## Models comparison
# Create a pandas dataframe that will allow you to compare your models.
#
# Find a sample frame below :
#
# |     | Model_Name     | Metric (metric_name)    | Details  |
# |:---:|:--------------:|:--------------:|:-----------------:|
# | 0   |  -             |  -             | -                 |
# | 1   |  -             |  -             | -                 |
#
#
# You might use the pandas dataframe method `.sort_values()` to sort the dataframe regarding the metric.

# %% [markdown]
# ## Hyperparameters tuning
#
# Fine-tune the Top-k models (3 < k < 5) using a ` GridSearchCV`  (that is in sklearn.model_selection
# ) to find the best hyperparameters and achieve the maximum performance of each of the Top-k models, then compare them again to select the best one.

# %%
# Code here

# %% [markdown]
# # Export key components
# Here is the section to **export** the important ML objects that will be use to develop an app: *Encoder, Scaler, ColumnTransformer, Model, Pipeline, etc*.

# %%
# Use pickle : put all your key components in a python dictionary and save it as a file that will be loaded in an app
